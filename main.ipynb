# %%
# %matplotlib widget
from matplotlib import pyplot as plt
from IPython.display import Audio
import scipy
import numpy as np
from IPython.display import HTML
HTML('''<style>.jupyter-matplotlib {background-color: #000;}.widget-label{color: #fff;}.jupyter-matplotlib-header{color: #000!important;}.jupyter-button {background-color: #333;color: #fff;}.cell-output-ipywidget-background {background-color:#000!important;}</style>''')
# Out:
# <style>.jupyter-matplotlib {background-color: #000;}.widget-label{color: #fff;}.jupyter-matplotlib-header{color: #000!important;}.jupyter-button {background-color: #333;color: #fff;}.cell-output-ipywidget-background {background-color:#000!important;}</style>

# %%
sample_rate, wave = scipy.io.wavfile.read('dataset/snr3.wav')
wave = np.mean(wave, axis=1) # convert stereo to mono

# plot the wave
plt.figure(figsize=(10, 4))
plt.plot(wave)
plt.title('Waveform')
# Out:
# C:\Users\jezersek\AppData\Local\Temp\ipykernel_24024\2191939473.py:1: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, wave = scipy.io.wavfile.read('dataset/snr3.wav')
# Text(0.5, 1.0, 'Waveform')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
